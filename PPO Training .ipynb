# %% [markdown]
# ![spreedsheet_finance](spreedsheet_finance.jpg)
#
# Your project is centered around developing a reinforcement learning (RL) simulation for stock trading in Python. This initiative is spearheaded by Quantum Trading, a fictional but ambitious trading firm looking to leverage cutting-edge machine learning techniques to gain a competitive edge in the financial markets. Quantum Trading is a small but highly specialised team of financial analysts, data scientists, and software engineers who are passionate about transforming the way trading decisions are made.
#
# In the fast-paced world of financial markets, staying ahead of the curve is crucial. Traditional trading strategies, while effective, often rely on historical data and predefined rules that may not adapt quickly to changing market conditions. Reinforcement learning, a subfield of machine learning where an agent learns to make decisions by interacting with an environment, offers a promising alternative. It allows the trading algorithms to learn and adapt in real-time, improving their performance as they gain more experience.
#
# By engaging with this project, you will gain valuable insights into the dynamic world of algorithmic trading and enhance your skill set in data science, finance, and machine learning. Remember, the journey of learning and experimentation is as important as the results. Good luck, and may your trading algorithms be ever profitable!
#
# ## The Data
# The provided data `AAPL.csv` contains historical prices for AAPL (the ticker symbol for Apple Inc) and you will be using this in your model. It has been loaded for you already in the sample code below and contains two columns, described below.
#
# | Column | Description |
# |--------|-------------|
# |`Date`    | The date corresponding to the closing price              |
# |`Close`   | The closing price of the security on the given date      |
#
# _**Disclaimer: This project is for educational purposes only. It is not financial advice, and should not be understood or construed as, financial advice.**_

# %%
# Make sure to run this cell to use gymnasium gym-anytrading stable-baselines3
# %pip install gymnasium gym-anytrading stable-baselines3
# Out:
# Requirement already satisfied: gymnasium in /opt/anaconda3/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: gym-anytrading in /opt/anaconda3/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: stable-baselines3 in /opt/anaconda3/lib/python3.12/site-packages (2.8.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gymnasium) (0.0.6)
# Requirement already satisfied: pandas>=0.24.2 in /opt/anaconda3/lib/python3.12/site-packages (from gym-anytrading) (2.2.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from gym-anytrading) (3.9.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /opt/anaconda3/lib/python3.12/site-packages (from stable-baselines3) (2.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.1.1->gym-anytrading) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->gym-anytrading) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=0.24.2->gym-anytrading) (2023.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.12/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym-anytrading) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import required packages
# Note that gym-anytrading is a gym environment specific for trading
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gymnasium as gym
import gym_anytrading
from gym_anytrading.envs import Actions
from stable_baselines3 import PPO

# Load the data provided
data = pd.read_csv("AAPL.csv", parse_dates=True, index_col='Date')

# Set window size (lookback window), start and end index of data
window_size = 10
start_index = window_size
end_index = len(data)

# Create the environment using the pre-built 'stocks-v0', passing in the data loaded above
# window_size is how far the environment can look back at each step
# frame_bound is the bounding box of the environment, the size of our data
env = gym.make('stocks-v0', df=data, window_size=window_size, frame_bound=(start_index, end_index))
print("Observation Space:", env.observation_space)

# Initialise cash balance tracking and other variables
balance = 100000
balance_history = [balance]
shares_held = 0
action_stats = {Actions.Sell: 0, Actions.Buy: 0}
observation, info = env.reset(seed=2024)
# Out:
# Observation Space: Box(-10000000000.0, 10000000000.0, (10, 2), float32)

# %%
# Start coding here by training the PPO model
model = PPO(policy = "MlpPolicy", env = env,verbose = 0) 
model.learn(total_timesteps = 10000)

observation, info = env.reset(seed = 2024)
step = 0
while True:
    action, _states = model.predict(observation)
    current_price = env.unwrapped.prices[env.unwrapped._current_tick]
    observation, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        break
    trade_amount = balance * 0.10  # Trade with 10% of current balance
    if action == Actions.Buy.value:
        shares_to_buy = trade_amount / current_price
        shares_held += shares_to_buy
        balance -= trade_amount
        print(f"{step}: BUY  {shares_to_buy:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
    elif action == Actions.Sell.value and shares_held > 0:
        balance += shares_held * current_price
        print(f"{step}: SELL {shares_held:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
        shares_held = 0
    else:print(f"{step}: HOLD | Current price: ${current_price:.2f} | Balance: ${balance:.2f}")
        
    action_stats[Actions(action)] += 1
    balance_history.append(balance)
    step += 1
    if terminated or truncated:
        break

if shares_held > 0:
    balance += shares_held*current_price
    print(f"\nFinal SELL {shares_held:.2f} shares at ${current_price:.2f} | Balance: ${balance:.2f}")
    shares_held = 0
    env.close()

print("Action stats:", action_stats)
print(f"Final Balance: ${balance:.2f}")
# Out:
# 0: BUY  1774.17 shares at $5.64 | Balance: $90000.00
# 1: SELL 1774.17 shares at $5.71 | Balance: $100137.50
# 2: HOLD | Current price: $5.72 | Balance: $100137.50
# 3: BUY  1752.41 shares at $5.71 | Balance: $90123.75
# 4: BUY  1576.87 shares at $5.72 | Balance: $81111.37
# 5: SELL 3329.28 shares at $5.81 | Balance: $100467.55
# 6: BUY  1721.70 shares at $5.84 | Balance: $90420.80
# 7: SELL 1721.70 shares at $5.94 | Balance: $100654.48
# 8: BUY  1702.40 shares at $5.91 | Balance: $90589.03
# 9: BUY  1536.24 shares at $5.90 | Balance: $81530.13
# 10: BUY  1392.74 shares at $5.85 | Balance: $73377.12
# 11: SELL 4631.39 shares at $5.91 | Balance: $100753.57
# 12: HOLD | Current price: $5.88 | Balance: $100753.57
# 13: BUY  1732.54 shares at $5.82 | Balance: $90678.22
# 14: SELL 1732.54 shares at $5.90 | Balance: $100907.03
# 15: HOLD | Current price: $6.01 | Balance: $100907.03
# 16: BUY  1694.09 shares at $5.96 | Balance: $90816.33
# 17: BUY  1593.37 shares at $5.70 | Balance: $81734.69
# 18: BUY  1395.47 shares at $5.86 | Balance: $73561.22
# 19: SELL 4682.92 shares at $5.88 | Balance: $101090.13
# 20: BUY  1701.75 shares at $5.94 | Balance: $90981.12
# 21: BUY  1505.42 shares at $6.04 | Balance: $81883.01
# 22: BUY  1356.16 shares at $6.04 | Balance: $73694.71
# 23: BUY  1218.09 shares at $6.05 | Balance: $66325.24
# 24: BUY  1109.32 shares at $5.98 | Balance: $59692.71
# 25: BUY  986.37 shares at $6.05 | Balance: $53723.44
# 26: BUY  884.60 shares at $6.07 | Balance: $48351.10
# 27: SELL 8761.70 shares at $6.01 | Balance: $100987.03
# 28: BUY  1710.61 shares at $5.90 | Balance: $90888.33
# 29: BUY  1540.67 shares at $5.90 | Balance: $81799.50
# 30: SELL 3251.28 shares at $5.95 | Balance: $101138.78
# 31: BUY  1662.78 shares at $6.08 | Balance: $91024.91
# 32: BUY  1473.83 shares at $6.18 | Balance: $81922.41
# 33: SELL 3136.62 shares at $6.11 | Balance: $101093.85
# 34: BUY  1640.37 shares at $6.16 | Balance: $90984.47
# 35: SELL 1640.37 shares at $6.15 | Balance: $101070.42
# 36: BUY  1629.04 shares at $6.20 | Balance: $90963.38
# 37: SELL 1629.04 shares at $6.26 | Balance: $101154.20
# 38: BUY  1557.33 shares at $6.50 | Balance: $91038.78
# 39: SELL 1557.33 shares at $6.59 | Balance: $101303.26
# 40: BUY  1533.07 shares at $6.61 | Balance: $91172.93
# 41: BUY  1387.26 shares at $6.57 | Balance: $82055.64
# 42: BUY  1245.42 shares at $6.59 | Balance: $73850.07
# 43: BUY  1114.72 shares at $6.62 | Balance: $66465.07
# 44: SELL 5280.48 shares at $6.57 | Balance: $101131.41
# 45: BUY  1552.71 shares at $6.51 | Balance: $91018.26
# 46: SELL 1552.71 shares at $6.65 | Balance: $101341.02
# 47: BUY  1530.67 shares at $6.62 | Balance: $91206.92
# 48: BUY  1377.82 shares at $6.62 | Balance: $82086.23
# 49: BUY  1270.83 shares at $6.46 | Balance: $73877.60
# 50: SELL 4179.31 shares at $6.60 | Balance: $101476.00
# 51: HOLD | Current price: $6.64 | Balance: $101476.00
# 52: BUY  1495.36 shares at $6.79 | Balance: $91328.40
# 53: SELL 1495.36 shares at $6.79 | Balance: $101488.81
# 54: BUY  1501.39 shares at $6.76 | Balance: $91339.93
# 55: BUY  1342.74 shares at $6.80 | Balance: $82205.94
# 56: BUY  1206.31 shares at $6.81 | Balance: $73985.35
# 57: BUY  1090.20 shares at $6.79 | Balance: $66586.81
# 58: BUY  974.66 shares at $6.83 | Balance: $59928.13
# 59: BUY  880.56 shares at $6.81 | Balance: $53935.32
# 60: BUY  803.08 shares at $6.72 | Balance: $48541.79
# 61: BUY  715.88 shares at $6.78 | Balance: $43687.61
# 62: SELL 8514.82 shares at $7.10 | Balance: $104130.65
# 63: BUY  1422.83 shares at $7.32 | Balance: $93717.59
# 64: BUY  1278.80 shares at $7.33 | Balance: $84345.83
# 65: BUY  1158.03 shares at $7.28 | Balance: $75911.25
# 66: SELL 3859.65 shares at $7.23 | Balance: $103822.06
# 67: BUY  1472.88 shares at $7.05 | Balance: $93439.85
# 68: BUY  1359.83 shares at $6.87 | Balance: $84095.87
# 69: SELL 2832.71 shares at $7.01 | Balance: $103960.24
# 70: HOLD | Current price: $6.73 | Balance: $103960.24
# 71: HOLD | Current price: $6.76 | Balance: $103960.24
# 72: BUY  1542.19 shares at $6.74 | Balance: $93564.21
# 73: BUY  1372.99 shares at $6.81 | Balance: $84207.79
# 74: BUY  1215.18 shares at $6.93 | Balance: $75787.01
# 75: BUY  1091.92 shares at $6.94 | Balance: $68208.31
# 76: BUY  948.00 shares at $7.20 | Balance: $61387.48
# 77: BUY  846.81 shares at $7.25 | Balance: $55248.73
# 78: BUY  761.11 shares at $7.26 | Balance: $49723.86
# 79: SELL 7778.20 shares at $7.21 | Balance: $105835.23
# 80: BUY  1449.44 shares at $7.30 | Balance: $95251.71
# 81: SELL 1449.44 shares at $7.38 | Balance: $105948.08
# 82: HOLD | Current price: $7.39 | Balance: $105948.08
# 83: BUY  1440.35 shares at $7.36 | Balance: $95353.27
# 84: BUY  1331.55 shares at $7.16 | Balance: $85817.94
# 85: SELL 2771.90 shares at $7.14 | Balance: $105609.32
# 86: HOLD | Current price: $7.35 | Balance: $105609.32
# 87: HOLD | Current price: $7.30 | Balance: $105609.32
# 88: HOLD | Current price: $7.29 | Balance: $105609.32
# 89: BUY  1474.18 shares at $7.16 | Balance: $95048.39
# 90: SELL 1474.18 shares at $7.14 | Balance: $105573.52
# 91: HOLD | Current price: $7.03 | Balance: $105573.52
# 92: HOLD | Current price: $7.01 | Balance: $105573.52
# 93: HOLD | Current price: $7.02 | Balance: $105573.52
# 94: BUY  1529.10 shares at $6.90 | Balance: $95016.17
# 95: BUY  1408.02 shares at $6.75 | Balance: $85514.55
# 96: SELL 2937.12 shares at $6.78 | Balance: $105431.37
# 97: BUY  1492.46 shares at $7.06 | Balance: $94888.24
# 98: SELL 1492.46 shares at $7.02 | Balance: $105358.35
# 99: HOLD | Current price: $6.95 | Balance: $105358.35
# 100: HOLD | Current price: $7.03 | Balance: $105358.35
# 101: HOLD | Current price: $6.93 | Balance: $105358.35
# 102: HOLD | Current price: $6.97 | Balance: $105358.35
# 103: BUY  1537.60 shares at $6.85 | Balance: $94822.51
# 104: BUY  1358.56 shares at $6.98 | Balance: $85340.26
# 105: SELL 2896.16 shares at $7.08 | Balance: $105844.01
# 106: BUY  1479.15 shares at $7.16 | Balance: $95259.61
# 107: BUY  1319.78 shares at $7.22 | Balance: $85733.65
# 108: BUY  1148.36 shares at $7.47 | Balance: $77160.28
# 109: SELL 3947.30 shares at $7.56 | Balance: $106991.97
# 110: BUY  1432.70 shares at $7.47 | Balance: $96292.77
# 111: SELL 1432.70 shares at $7.56 | Balance: $107121.93
# 112: HOLD | Current price: $7.53 | Balance: $107121.93
# 113: BUY  1401.53 shares at $7.64 | Balance: $96409.74
# 114: SELL 1401.53 shares at $7.66 | Balance: $107140.45
# 115: HOLD | Current price: $7.53 | Balance: $107140.45
# 116: HOLD | Current price: $7.52 | Balance: $107140.45
# 117: HOLD | Current price: $7.57 | Balance: $107140.45
# 118: BUY  1427.79 shares at $7.50 | Balance: $96426.41
# 119: BUY  1299.80 shares at $7.42 | Balance: $86783.77
# 120: BUY  1153.55 shares at $7.52 | Balance: $78105.39
# 121: SELL 3881.14 shares at $7.48 | Balance: $107134.90
# 122: BUY  1456.70 shares at $7.35 | Balance: $96421.41
# 123: BUY  1255.49 shares at $7.68 | Balance: $86779.27
# 124: SELL 2712.18 shares at $7.56 | Balance: $107288.23
# 125: HOLD | Current price: $7.43 | Balance: $107288.23
# 126: BUY  1519.13 shares at $7.06 | Balance: $96559.40
# 127: SELL 1519.13 shares at $7.25 | Balance: $107576.86
# 128: BUY  1462.64 shares at $7.36 | Balance: $96819.18
# 129: SELL 1462.64 shares at $7.42 | Balance: $107678.20
# 130: HOLD | Current price: $7.12 | Balance: $107678.20
# 131: BUY  1569.82 shares at $6.86 | Balance: $96910.38
# 132: BUY  1393.46 shares at $6.95 | Balance: $87219.34
# 133: BUY  1246.88 shares at $6.99 | Balance: $78497.41
# 134: BUY  1103.21 shares at $7.12 | Balance: $70647.67
# 135: BUY  1030.01 shares at $6.86 | Balance: $63582.90
# 136: BUY  910.84 shares at $6.98 | Balance: $57224.61
# 137: BUY  825.41 shares at $6.93 | Balance: $51502.15
# 138: BUY  735.03 shares at $7.01 | Balance: $46351.93
# 139: BUY  665.16 shares at $6.97 | Balance: $41716.74
# 140: BUY  587.94 shares at $7.10 | Balance: $37545.07
# 141: BUY  524.63 shares at $7.16 | Balance: $33790.56
# 142: SELL 10592.40 shares at $7.26 | Balance: $110736.77
# 143: BUY  1530.80 shares at $7.23 | Balance: $99663.09
# 144: BUY  1375.14 shares at $7.25 | Balance: $89696.78
# 145: BUY  1245.36 shares at $7.20 | Balance: $80727.11
# 146: SELL 4151.29 shares at $7.16 | Balance: $110441.45
# 147: BUY  1569.25 shares at $7.04 | Balance: $99397.31
# 148: SELL 1569.25 shares at $7.17 | Balance: $110643.21
# 149: BUY  1533.67 shares at $7.21 | Balance: $99578.89
# 150: SELL 1533.67 shares at $7.31 | Balance: $110786.72
# 151: HOLD | Current price: $7.46 | Balance: $110786.72
# 152: BUY  1485.29 shares at $7.46 | Balance: $99708.05
# 153: SELL 1485.29 shares at $7.48 | Balance: $110812.18
# 154: BUY  1472.52 shares at $7.53 | Balance: $99730.96
# 155: BUY  1275.39 shares at $7.82 | Balance: $89757.87
# 156: SELL 2747.91 shares at $7.82 | Balance: $111258.28
# 157: BUY  1396.84 shares at $7.97 | Balance: $100132.45
# 158: SELL 1396.84 shares at $8.03 | Balance: $111349.08
# 159: HOLD | Current price: $8.05 | Balance: $111349.08
# 160: BUY  1375.89 shares at $8.09 | Balance: $100214.17
# 161: SELL 1375.89 shares at $7.99 | Balance: $111213.45
# 162: BUY  1387.38 shares at $8.02 | Balance: $100092.11
# 163: BUY  1250.48 shares at $8.00 | Balance: $90082.90
# 164: BUY  1122.78 shares at $8.02 | Balance: $81074.61
# 165: SELL 3760.64 shares at $7.94 | Balance: $110924.69
# 166: BUY  1381.93 shares at $8.03 | Balance: $99832.22
# 167: SELL 1381.93 shares at $8.16 | Balance: $111102.86
# 168: HOLD | Current price: $8.19 | Balance: $111102.86
# 169: BUY  1372.55 shares at $8.09 | Balance: $99992.57
# 170: BUY  1212.56 shares at $8.25 | Balance: $89993.32
# 171: BUY  1084.30 shares at $8.30 | Balance: $80993.99
# 172: BUY  961.56 shares at $8.42 | Balance: $72894.59
# 173: SELL 4630.96 shares at $8.39 | Balance: $111761.61
# 174: BUY  1326.15 shares at $8.43 | Balance: $100585.45
# 175: BUY  1180.93 shares at $8.52 | Balance: $90526.90
# 176: BUY  1058.18 shares at $8.56 | Balance: $81474.21
# 177: SELL 3565.26 shares at $8.59 | Balance: $112109.95
# 178: BUY  1308.22 shares at $8.57 | Balance: $100898.95
# 179: SELL 1308.22 shares at $8.64 | Balance: $112195.92
# 180: HOLD | Current price: $8.65 | Balance: $112195.92
# 181: HOLD | Current price: $8.66 | Balance: $112195.92
# 182: BUY  1278.64 shares at $8.77 | Balance: $100976.32
# 183: BUY  1135.84 shares at $8.89 | Balance: $90878.69
# 184: SELL 2414.48 shares at $8.84 | Balance: $112212.34
# 185: BUY  1271.68 shares at $8.82 | Balance: $100991.11
# 186: SELL 1271.68 shares at $8.74 | Balance: $112099.71
# 187: HOLD | Current price: $9.26 | Balance: $112099.71
# 188: BUY  1177.92 shares at $9.52 | Balance: $100889.74
# 189: BUY  1043.06 shares at $9.67 | Balance: $90800.76
# 190: BUY  943.38 shares at $9.62 | Balance: $81720.69
# 191: BUY  873.22 shares at $9.36 | Balance: $73548.62
# 192: SELL 4037.58 shares at $9.34 | Balance: $111271.11
# 193: HOLD | Current price: $9.59 | Balance: $111271.11
# 194: BUY  1193.30 shares at $9.32 | Balance: $100144.00
# 195: BUY  1052.76 shares at $9.51 | Balance: $90129.60
# 196: SELL 2246.06 shares at $9.24 | Balance: $110880.02
# 197: HOLD | Current price: $9.14 | Balance: $110880.02
# 198: HOLD | Current price: $8.79 | Balance: $110880.02
# 199: BUY  1316.31 shares at $8.42 | Balance: $99792.02
# 200: SELL 1316.31 shares at $9.07 | Balance: $111732.33
# 201: HOLD | Current price: $9.16 | Balance: $111732.33
# 202: HOLD | Current price: $9.36 | Balance: $111732.33
# 203: BUY  1210.91 shares at $9.23 | Balance: $100559.09
# 204: BUY  1109.31 shares at $9.06 | Balance: $90503.18
# 205: BUY  996.81 shares at $9.08 | Balance: $81452.87
# 206: SELL 3317.03 shares at $9.01 | Balance: $111348.79
# 207: BUY  1255.44 shares at $8.87 | Balance: $100213.91
# 208: BUY  1180.18 shares at $8.49 | Balance: $90192.52
# 209: BUY  1042.17 shares at $8.65 | Balance: $81173.27
# 210: BUY  921.08 shares at $8.81 | Balance: $73055.94
# 211: SELL 4398.87 shares at $8.76 | Balance: $111580.61
# 212: HOLD | Current price: $8.72 | Balance: $111580.61
# 213: BUY  1233.18 shares at $9.05 | Balance: $100422.55
# 214: SELL 1233.18 shares at $9.17 | Balance: $111736.08
# 215: BUY  1199.48 shares at $9.32 | Balance: $100562.47
# 216: SELL 1199.48 shares at $9.43 | Balance: $111869.74
# 217: BUY  1190.47 shares at $9.40 | Balance: $100682.76
# 218: BUY  1101.39 shares at $9.14 | Balance: $90614.49
# 219: BUY  1011.08 shares at $8.96 | Balance: $81553.04
# 220: BUY  915.85 shares at $8.90 | Balance: $73397.73
# 221: BUY  845.04 shares at $8.69 | Balance: $66057.96
# 222: SELL 5063.82 shares at $8.95 | Balance: $111362.91
# 223: BUY  1230.00 shares at $9.05 | Balance: $100226.62
# 224: SELL 1230.00 shares at $9.08 | Balance: $111396.73
# 225: BUY  1201.09 shares at $9.27 | Balance: $100257.06
# 226: SELL 1201.09 shares at $9.54 | Balance: $111721.03
# 227: BUY  1150.62 shares at $9.71 | Balance: $100548.92
# 228: BUY  1027.24 shares at $9.79 | Balance: $90494.03
# 229: SELL 2177.86 shares at $9.65 | Balance: $111508.09
# 230: BUY  1140.12 shares at $9.78 | Balance: $100357.28
# 231: SELL 1140.12 shares at $9.68 | Balance: $111390.82
# 232: HOLD | Current price: $9.61 | Balance: $111390.82
# 233: HOLD | Current price: $9.52 | Balance: $111390.82
# 234: BUY  1162.48 shares at $9.58 | Balance: $100251.74
# 235: SELL 1162.48 shares at $9.15 | Balance: $110887.21
# 236: HOLD | Current price: $8.98 | Balance: $110887.21
# 237: BUY  1249.53 shares at $8.87 | Balance: $99798.49
# 238: SELL 1249.53 shares at $8.82 | Balance: $110818.49
# 239: BUY  1248.01 shares at $8.88 | Balance: $99736.64
# 240: BUY  1079.61 shares at $9.24 | Balance: $89762.98
# 241: BUY  973.83 shares at $9.22 | Balance: $80786.68
# 242: BUY  871.28 shares at $9.27 | Balance: $72708.01
# 243: BUY  791.26 shares at $9.19 | Balance: $65437.21
# 244: BUY  727.66 shares at $8.99 | Balance: $58893.49
# 245: SELL 5691.65 shares at $9.03 | Balance: $110266.69
# 246: BUY  1227.87 shares at $8.98 | Balance: $99240.02
# 247: BUY  1111.93 shares at $8.93 | Balance: $89316.02
# 248: BUY  1018.34 shares at $8.77 | Balance: $80384.41
# 249: SELL 3358.14 shares at $9.00 | Balance: $110594.50
# 250: BUY  1218.00 shares at $9.08 | Balance: $99535.05
# 251: SELL 1218.00 shares at $9.25 | Balance: $110802.43
# 252: HOLD | Current price: $9.28 | Balance: $110802.43
# 253: BUY  1196.57 shares at $9.26 | Balance: $99722.18
# 254: BUY  1057.34 shares at $9.43 | Balance: $89749.97
# 255: BUY  962.98 shares at $9.32 | Balance: $80774.97
# 256: BUY  876.25 shares at $9.22 | Balance: $72697.47
# 257: BUY  791.27 shares at $9.19 | Balance: $65427.73
# 258: BUY  699.63 shares at $9.35 | Balance: $58884.95
# 259: BUY  629.47 shares at $9.35 | Balance: $52996.46
# 260: SELL 6213.51 shares at $9.39 | Balance: $111354.65
# 261: HOLD | Current price: $9.35 | Balance: $111354.65
# 262: BUY  1198.79 shares at $9.29 | Balance: $100219.19
# 263: BUY  1072.07 shares at $9.35 | Balance: $90197.27
# 264: BUY  973.56 shares at $9.26 | Balance: $81177.54
# 265: BUY  908.50 shares at $8.94 | Balance: $73059.79
# 266: BUY  812.45 shares at $8.99 | Balance: $65753.81
# 267: BUY  739.10 shares at $8.90 | Balance: $59178.43
# 268: BUY  669.11 shares at $8.84 | Balance: $53260.59
# 269: SELL 6373.59 shares at $9.00 | Balance: $110616.07
# 270: HOLD | Current price: $9.04 | Balance: $110616.07
# 271: BUY  1239.49 shares at $8.92 | Balance: $99554.46
# 272: SELL 1239.49 shares at $8.92 | Balance: $110605.44
# 273: BUY  1259.95 shares at $8.78 | Balance: $99544.90
# 274: SELL 1259.95 shares at $8.57 | Balance: $110341.31
# 275: BUY  1272.00 shares at $8.67 | Balance: $99307.18
# 276: SELL 1272.00 shares at $8.58 | Balance: $110222.74
# 277: HOLD | Current price: $8.63 | Balance: $110222.74
# 278: HOLD | Current price: $8.66 | Balance: $110222.74
# 279: HOLD | Current price: $8.68 | Balance: $110222.74
# 280: HOLD | Current price: $8.94 | Balance: $110222.74
# 281: BUY  1223.87 shares at $9.01 | Balance: $99200.46
# 282: SELL 1223.87 shares at $9.24 | Balance: $110511.22
# 283: HOLD | Current price: $9.21 | Balance: $110511.22
# 284: BUY  1176.90 shares at $9.39 | Balance: $99460.10
# 285: BUY  1058.61 shares at $9.40 | Balance: $89514.09
# 286: BUY  951.52 shares at $9.41 | Balance: $80562.68
# 287: BUY  844.73 shares at $9.54 | Balance: $72506.41
# 288: BUY  757.36 shares at $9.57 | Balance: $65255.77
# 289: SELL 4789.12 shares at $9.65 | Balance: $111474.16
# 290: HOLD | Current price: $9.88 | Balance: $111474.16
# 291: HOLD | Current price: $9.83 | Balance: $111474.16
# 292: BUY  1102.03 shares at $10.12 | Balance: $100326.75
# 293: SELL 1102.03 shares at $10.13 | Balance: $111495.42
# 294: HOLD | Current price: $10.28 | Balance: $111495.42
# 295: HOLD | Current price: $10.32 | Balance: $111495.42
# 296: BUY  1067.96 shares at $10.44 | Balance: $100345.87
# 297: BUY  965.00 shares at $10.40 | Balance: $90311.29
# 298: SELL 2032.96 shares at $10.24 | Balance: $111138.97
# 299: HOLD | Current price: $10.26 | Balance: $111138.97
# 300: HOLD | Current price: $10.13 | Balance: $111138.97
# 301: BUY  1101.48 shares at $10.09 | Balance: $100025.07
# 302: SELL 1101.48 shares at $9.95 | Balance: $110986.34
# 303: BUY  1075.52 shares at $10.32 | Balance: $99887.70
# 304: BUY  967.13 shares at $10.33 | Balance: $89898.93
# 305: SELL 2042.66 shares at $10.33 | Balance: $110998.13
# 306: HOLD | Current price: $10.50 | Balance: $110998.13
# 307: BUY  1052.26 shares at $10.55 | Balance: $99898.31
# 308: BUY  936.94 shares at $10.66 | Balance: $89908.48
# 309: BUY  838.75 shares at $10.72 | Balance: $80917.63
# 310: BUY  749.46 shares at $10.80 | Balance: $72825.87
# 311: SELL 3577.42 shares at $11.24 | Balance: $113038.59
# 312: BUY  995.31 shares at $11.36 | Balance: $101734.73
# 313: SELL 995.31 shares at $11.05 | Balance: $112736.08
# 314: BUY  1016.52 shares at $11.09 | Balance: $101462.47
# 315: SELL 1016.52 shares at $11.05 | Balance: $112699.42
# 316: BUY  1026.31 shares at $10.98 | Balance: $101429.47
# 317: SELL 1026.31 shares at $11.03 | Balance: $112749.63
# 318: HOLD | Current price: $11.00 | Balance: $112749.63
# 319: HOLD | Current price: $10.99 | Balance: $112749.63
# 320: HOLD | Current price: $10.90 | Balance: $112749.63
# 321: BUY  1048.90 shares at $10.75 | Balance: $101474.67
# 322: SELL 1048.90 shares at $10.86 | Balance: $112869.51
# 323: BUY  1021.58 shares at $11.05 | Balance: $101582.55
# 324: SELL 1021.58 shares at $11.17 | Balance: $112995.01
# 325: BUY  994.08 shares at $11.37 | Balance: $101695.51
# 326: BUY  897.89 shares at $11.33 | Balance: $91525.96
# 327: BUY  804.32 shares at $11.38 | Balance: $82373.37
# 328: BUY  729.71 shares at $11.29 | Balance: $74136.03
# 329: SELL 3426.00 shares at $11.36 | Balance: $113049.23
# 330: BUY  999.65 shares at $11.31 | Balance: $101744.30
# 331: BUY  924.86 shares at $11.00 | Balance: $91569.87
# 332: SELL 1924.50 shares at $10.97 | Balance: $112673.43
# 333: BUY  1046.07 shares at $10.77 | Balance: $101406.09
# 334: SELL 1046.07 shares at $10.73 | Balance: $112632.71
# 335: BUY  1022.51 shares at $11.02 | Balance: $101369.44
# 336: BUY  925.36 shares at $10.95 | Balance: $91232.50
# 337: SELL 1947.86 shares at $11.19 | Balance: $113031.86
# 338: HOLD | Current price: $11.03 | Balance: $113031.86
# 339: BUY  1005.37 shares at $11.24 | Balance: $101728.67
# 340: SELL 1005.37 shares at $11.25 | Balance: $113039.04
# 341: BUY  998.86 shares at $11.32 | Balance: $101735.13
# 342: BUY  915.50 shares at $11.11 | Balance: $91561.62
# 343: BUY  810.28 shares at $11.30 | Balance: $82405.46
# 344: SELL 2724.64 shares at $11.36 | Balance: $113364.22
# 345: HOLD | Current price: $11.34 | Balance: $113364.22
# 346: BUY  991.47 shares at $11.43 | Balance: $102027.80
# 347: BUY  897.77 shares at $11.36 | Balance: $91825.02
# 348: SELL 1889.24 shares at $11.46 | Balance: $113484.45
# 349: BUY  993.73 shares at $11.42 | Balance: $102136.00
# 350: BUY  892.13 shares at $11.45 | Balance: $91922.40
# 351: SELL 1885.86 shares at $11.49 | Balance: $113587.60
# 352: BUY  992.99 shares at $11.44 | Balance: $102228.84
# 353: BUY  893.50 shares at $11.44 | Balance: $92005.95
# 354: SELL 1886.49 shares at $11.47 | Balance: $113650.04
# 355: BUY  992.55 shares at $11.45 | Balance: $102285.04
# 356: SELL 992.55 shares at $11.51 | Balance: $113706.76
# 357: HOLD | Current price: $11.58 | Balance: $113706.76
# 358: BUY  979.15 shares at $11.61 | Balance: $102336.08
# 359: SELL 979.15 shares at $11.56 | Balance: $113652.21
# 360: HOLD | Current price: $11.60 | Balance: $113652.21
# 361: HOLD | Current price: $11.62 | Balance: $113652.21
# 362: HOLD | Current price: $11.62 | Balance: $113652.21
# 363: BUY  983.21 shares at $11.56 | Balance: $102286.99
# 364: BUY  887.91 shares at $11.52 | Balance: $92058.29
# 365: SELL 1871.12 shares at $11.77 | Balance: $114082.03
# 366: BUY  964.20 shares at $11.83 | Balance: $102673.83
# 367: BUY  860.74 shares at $11.93 | Balance: $92406.44
# 368: SELL 1824.94 shares at $11.92 | Balance: $114157.75
# 369: BUY  950.97 shares at $12.00 | Balance: $102741.98
# 370: SELL 950.97 shares at $12.23 | Balance: $114372.74
# 371: HOLD | Current price: $12.20 | Balance: $114372.74
# 372: HOLD | Current price: $12.30 | Balance: $114372.74
# 373: BUY  926.42 shares at $12.35 | Balance: $102935.47
# 374: SELL 926.42 shares at $12.45 | Balance: $114465.38
# 375: HOLD | Current price: $12.17 | Balance: $114465.38
# 376: HOLD | Current price: $12.10 | Balance: $114465.38
# 377: BUY  963.40 shares at $11.88 | Balance: $103018.84
# 378: SELL 963.40 shares at $11.67 | Balance: $114260.32
# 379: BUY  948.08 shares at $12.05 | Balance: $102834.28
# 380: SELL 948.08 shares at $12.19 | Balance: $114394.06
# 381: HOLD | Current price: $12.28 | Balance: $114394.06
# 382: BUY  933.26 shares at $12.26 | Balance: $102954.66
# 383: SELL 933.26 shares at $12.00 | Balance: $114157.08
# 384: HOLD | Current price: $12.12 | Balance: $114157.08
# 385: HOLD | Current price: $12.32 | Balance: $114157.08
# 386: HOLD | Current price: $12.30 | Balance: $114157.08
# 387: BUY  930.70 shares at $12.27 | Balance: $102741.37
# 388: BUY  830.23 shares at $12.38 | Balance: $92467.24
# 389: SELL 1760.93 shares at $12.57 | Balance: $114597.15
# 390: HOLD | Current price: $12.69 | Balance: $114597.15
# 391: BUY  895.89 shares at $12.79 | Balance: $103137.43
# 392: SELL 895.89 shares at $12.66 | Balance: $114481.32
# 393: HOLD | Current price: $12.74 | Balance: $114481.32
# 394: BUY  892.44 shares at $12.83 | Balance: $103033.19
# 395: BUY  801.59 shares at $12.85 | Balance: $92729.87
# 396: BUY  715.02 shares at $12.97 | Balance: $83456.88
# 397: SELL 2409.05 shares at $12.80 | Balance: $114284.13
# 398: BUY  912.81 shares at $12.52 | Balance: $102855.71
# 399: BUY  850.52 shares at $12.09 | Balance: $92570.14
# 400: SELL 1763.34 shares at $12.24 | Balance: $114147.09
# 401: HOLD | Current price: $12.25 | Balance: $114147.09
# 402: HOLD | Current price: $12.43 | Balance: $114147.09
# 403: BUY  904.88 shares at $12.61 | Balance: $102732.38
# 404: BUY  823.48 shares at $12.48 | Balance: $92459.14
# 405: SELL 1728.36 shares at $12.58 | Balance: $114194.50
# 406: BUY  889.27 shares at $12.84 | Balance: $102775.05
# 407: BUY  799.36 shares at $12.86 | Balance: $92497.55
# 408: BUY  728.82 shares at $12.69 | Balance: $83247.79
# 409: BUY  655.20 shares at $12.71 | Balance: $74923.01
# 410: BUY  595.18 shares at $12.59 | Balance: $67430.71
# 411: BUY  544.63 shares at $12.38 | Balance: $60687.64
# 412: BUY  482.76 shares at $12.57 | Balance: $54618.88
# 413: SELL 4695.21 shares at $12.63 | Balance: $113906.02
# 414: HOLD | Current price: $12.34 | Balance: $113906.02
# 415: BUY  966.45 shares at $11.79 | Balance: $102515.41
# 416: BUY  857.77 shares at $11.95 | Balance: $92263.87
# 417: BUY  781.26 shares at $11.81 | Balance: $83037.49
# 418: BUY  685.25 shares at $12.12 | Balance: $74733.74
# 419: BUY  613.29 shares at $12.19 | Balance: $67260.36
# 420: BUY  555.23 shares at $12.11 | Balance: $60534.33
# 421: BUY  491.34 shares at $12.32 | Balance: $54480.89
# 422: BUY  433.94 shares at $12.56 | Balance: $49032.80
# 423: BUY  391.77 shares at $12.52 | Balance: $44129.52
# 424: BUY  352.07 shares at $12.53 | Balance: $39716.57
# 425: BUY  318.98 shares at $12.45 | Balance: $35744.91
# 426: BUY  287.18 shares at $12.45 | Balance: $32170.42
# 427: BUY  261.43 shares at $12.31 | Balance: $28953.38
# 428: BUY  237.61 shares at $12.19 | Balance: $26058.04
# 429: SELL 7233.55 shares at $12.10 | Balance: $113607.30
# 430: HOLD | Current price: $12.07 | Balance: $113607.30
# 431: HOLD | Current price: $12.07 | Balance: $113607.30
# 432: HOLD | Current price: $11.97 | Balance: $113607.30
# 433: BUY  961.61 shares at $11.81 | Balance: $102246.57
# 434: BUY  861.28 shares at $11.87 | Balance: $92021.91
# 435: BUY  766.55 shares at $12.00 | Balance: $82819.72
# 436: SELL 2589.44 shares at $11.87 | Balance: $113561.98
# 437: HOLD | Current price: $11.69 | Balance: $113561.98
# 438: BUY  958.18 shares at $11.85 | Balance: $102205.78
# 439: BUY  847.03 shares at $12.07 | Balance: $91985.20
# 440: SELL 1805.21 shares at $12.23 | Balance: $114060.99
# 441: HOLD | Current price: $12.52 | Balance: $114060.99
# 442: BUY  904.71 shares at $12.61 | Balance: $102654.89
# 443: BUY  820.25 shares at $12.52 | Balance: $92389.40
# 444: SELL 1724.96 shares at $12.51 | Balance: $113960.67
# 445: BUY  920.23 shares at $12.38 | Balance: $102564.60
# 446: BUY  820.21 shares at $12.50 | Balance: $92308.14
# 447: SELL 1740.44 shares at $12.37 | Balance: $113832.44
# 448: BUY  915.37 shares at $12.44 | Balance: $102449.20
# 449: BUY  820.60 shares at $12.48 | Balance: $92204.28
# 450: SELL 1735.97 shares at $12.38 | Balance: $113702.40
# 451: HOLD | Current price: $12.38 | Balance: $113702.40
# 452: HOLD | Current price: $12.41 | Balance: $113702.40
# 453: HOLD | Current price: $12.48 | Balance: $113702.40
# 454: BUY  916.88 shares at $12.40 | Balance: $102332.16
# 455: BUY  826.76 shares at $12.38 | Balance: $92098.94
# 456: BUY  757.35 shares at $12.16 | Balance: $82889.05
# 457: BUY  696.34 shares at $11.90 | Balance: $74600.14
# 458: BUY  621.41 shares at $12.01 | Balance: $67140.13
# 459: BUY  553.13 shares at $12.14 | Balance: $60426.12
# 460: BUY  496.85 shares at $12.16 | Balance: $54383.50
# 461: SELL 4868.71 shares at $11.97 | Balance: $112672.43
# 462: BUY  943.43 shares at $11.94 | Balance: $101405.18
# 463: SELL 943.43 shares at $11.86 | Balance: $112597.96
# 464: HOLD | Current price: $12.03 | Balance: $112597.96
# 465: BUY  941.12 shares at $11.96 | Balance: $101338.17
# 466: BUY  840.96 shares at $12.05 | Balance: $91204.35
# 467: BUY  734.19 shares at $12.42 | Balance: $82083.91
# 468: BUY  665.20 shares at $12.34 | Balance: $73875.52
# 469: BUY  597.66 shares at $12.36 | Balance: $66487.97
# 470: BUY  542.06 shares at $12.27 | Balance: $59839.17
# 471: SELL 4321.19 shares at $12.07 | Balance: $112008.31
# 472: HOLD | Current price: $11.86 | Balance: $112008.31
# 473: BUY  943.97 shares at $11.87 | Balance: $100807.48
# 474: BUY  851.49 shares at $11.84 | Balance: $90726.73
# 475: BUY  779.49 shares at $11.64 | Balance: $81654.06
# 476: SELL 2574.94 shares at $11.66 | Balance: $111688.95
# 477: BUY  940.71 shares at $11.87 | Balance: $100520.05
# 478: BUY  861.38 shares at $11.67 | Balance: $90468.05
# 479: SELL 1802.09 shares at $11.61 | Balance: $111395.45
# 480: BUY  973.92 shares at $11.44 | Balance: $100255.90
# 481: SELL 973.92 shares at $11.26 | Balance: $111223.62
# 482: BUY  957.35 shares at $11.62 | Balance: $100101.26
# 483: SELL 957.35 shares at $11.52 | Balance: $111131.65
# 484: BUY  939.43 shares at $11.83 | Balance: $100018.48
# 485: SELL 939.43 shares at $11.66 | Balance: $110967.92
# 486: BUY  935.76 shares at $11.86 | Balance: $99871.13
# 487: BUY  834.10 shares at $11.97 | Balance: $89884.01
# 488: SELL 1769.86 shares at $11.93 | Balance: $110998.42
# 489: BUY  925.90 shares at $11.99 | Balance: $99898.58
# 490: BUY  814.88 shares at $12.26 | Balance: $89908.72
# 491: BUY  720.44 shares at $12.48 | Balance: $80917.85
# 492: BUY  644.10 shares at $12.56 | Balance: $72826.06
# 493: BUY  570.86 shares at $12.76 | Balance: $65543.46
# 494: BUY  510.19 shares at $12.85 | Balance: $58989.11
# 495: BUY  466.58 shares at $12.64 | Balance: $53090.20
# 496: SELL 4652.96 shares at $12.63 | Balance: $111875.40
# 497: BUY  874.95 shares at $12.79 | Balance: $100687.86
# 498: SELL 874.95 shares at $12.78 | Balance: $111867.59
# 499: BUY  858.35 shares at $13.03 | Balance: $100680.83
# 500: SELL 858.35 shares at $13.35 | Balance: $112139.81
# 501: BUY  833.20 shares at $13.46 | Balance: $100925.83
# 502: BUY  730.40 shares at $13.82 | Balance: $90833.25
# 503: BUY  656.70 shares at $13.83 | Balance: $81749.92
# 504: BUY  582.00 shares at $14.05 | Balance: $73574.93
# 505: BUY  516.96 shares at $14.23 | Balance: $66217.44
# 506: BUY  459.60 shares at $14.41 | Balance: $59595.69
# 507: SELL 3778.87 shares at $14.02 | Balance: $112579.44
# 508: HOLD | Current price: $13.99 | Balance: $112579.44
# 509: HOLD | Current price: $13.95 | Balance: $112579.44
# 510: HOLD | Current price: $14.17 | Balance: $112579.44
# 511: HOLD | Current price: $13.89 | Balance: $112579.44
# 512: HOLD | Current price: $14.02 | Balance: $112579.44
# 513: BUY  835.31 shares at $13.48 | Balance: $101321.50
# 514: SELL 835.31 shares at $13.34 | Balance: $112467.57
# 515: BUY  891.56 shares at $12.61 | Balance: $101220.81
# 516: SELL 891.56 shares at $13.36 | Balance: $113129.87
# 517: HOLD | Current price: $12.99 | Balance: $113129.87
# 518: BUY  847.64 shares at $13.35 | Balance: $101816.89
# 519: BUY  756.22 shares at $13.46 | Balance: $91635.20
# 520: BUY  669.20 shares at $13.69 | Balance: $82471.68
# 521: BUY  606.92 shares at $13.59 | Balance: $74224.51
# 522: SELL 2879.98 shares at $13.59 | Balance: $113355.24
# 523: BUY  867.08 shares at $13.07 | Balance: $102019.72
# 524: SELL 867.08 shares at $12.72 | Balance: $113044.95
# 525: HOLD | Current price: $12.73 | Balance: $113044.95
# 526: BUY  847.23 shares at $13.34 | Balance: $101740.45
# 527: SELL 847.23 shares at $13.44 | Balance: $113123.01
# 528: HOLD | Current price: $13.35 | Balance: $113123.01
# 529: BUY  825.76 shares at $13.70 | Balance: $101810.71
# 530: SELL 825.76 shares at $13.93 | Balance: $113311.46
# 531: BUY  813.54 shares at $13.93 | Balance: $101980.32
# 532: BUY  742.00 shares at $13.74 | Balance: $91782.29
# 533: BUY  674.46 shares at $13.61 | Balance: $82604.06
# 534: SELL 2230.00 shares at $13.36 | Balance: $112394.52
# 535: HOLD | Current price: $13.56 | Balance: $112394.52
# 536: BUY  819.69 shares at $13.71 | Balance: $101155.07
# 537: BUY  737.32 shares at $13.72 | Balance: $91039.56
# 538: SELL 1557.01 shares at $13.48 | Balance: $112030.32
# 539: BUY  825.62 shares at $13.57 | Balance: $100827.29
# 540: BUY  734.01 shares at $13.74 | Balance: $90744.56
# 541: BUY  652.67 shares at $13.90 | Balance: $81670.11
# 542: BUY  581.93 shares at $14.03 | Balance: $73503.10
# 543: SELL 2794.23 shares at $14.30 | Balance: $113470.63
# 544: BUY  771.85 shares at $14.70 | Balance: $102123.56
# 545: SELL 771.85 shares at $14.77 | Balance: $113520.80
# 546: BUY  771.24 shares at $14.72 | Balance: $102168.72
# 547: BUY  711.94 shares at $14.35 | Balance: $91951.85
# 548: BUY  636.82 shares at $14.44 | Balance: $82756.66
# 549: BUY  574.74 shares at $14.40 | Balance: $74480.99
# 550: SELL 2694.74 shares at $14.26 | Balance: $112906.05
# 551: BUY  796.29 shares at $14.18 | Balance: $101615.44
# 552: BUY  728.48 shares at $13.95 | Balance: $91453.90
# 553: BUY  671.54 shares at $13.62 | Balance: $82308.51
# 554: BUY  615.23 shares at $13.38 | Balance: $74077.66
# 555: SELL 2811.54 shares at $13.30 | Balance: $111481.20
# 556: BUY  825.24 shares at $13.51 | Balance: $100333.08
# 557: BUY  744.45 shares at $13.48 | Balance: $90299.77
# 558: SELL 1569.69 shares at $13.21 | Balance: $111030.88
# 559: BUY  799.58 shares at $13.89 | Balance: $99927.80
# 560: BUY  698.99 shares at $14.30 | Balance: $89935.02
# 561: SELL 1498.57 shares at $14.36 | Balance: $111460.40
# 562: BUY  764.12 shares at $14.59 | Balance: $100314.36
# 563: BUY  665.59 shares at $15.07 | Balance: $90282.93
# 564: BUY  601.90 shares at $15.00 | Balance: $81254.63
# 565: BUY  538.82 shares at $15.08 | Balance: $73129.17
# 566: BUY  513.68 shares at $14.24 | Balance: $65816.25
# 567: SELL 3084.11 shares at $14.12 | Balance: $109358.41
# 568: BUY  779.40 shares at $14.03 | Balance: $98422.57
# 569: BUY  679.16 shares at $14.49 | Balance: $88580.32
# 570: SELL 1458.56 shares at $14.21 | Balance: $109300.76
# 571: BUY  763.96 shares at $14.31 | Balance: $98370.69
# 572: BUY  680.61 shares at $14.45 | Balance: $88533.62
# 573: SELL 1444.57 shares at $14.46 | Balance: $109425.77
# 574: BUY  756.94 shares at $14.46 | Balance: $98483.19
# 575: BUY  695.45 shares at $14.16 | Balance: $88634.87
# 576: BUY  624.49 shares at $14.19 | Balance: $79771.39
# 577: BUY  554.15 shares at $14.40 | Balance: $71794.25
# 578: BUY  502.26 shares at $14.29 | Balance: $64614.82
# 579: SELL 3133.28 shares at $14.28 | Balance: $109345.72
# 580: BUY  753.68 shares at $14.51 | Balance: $98411.15
# 581: SELL 753.68 shares at $14.12 | Balance: $109050.97
# 582: BUY  792.65 shares at $13.76 | Balance: $98145.88
# 583: BUY  714.49 shares at $13.74 | Balance: $88331.29
# 584: SELL 1507.14 shares at $13.55 | Balance: $108745.48
# 585: BUY  783.09 shares at $13.89 | Balance: $97870.93
# 586: BUY  712.21 shares at $13.74 | Balance: $88083.84
# 587: BUY  653.49 shares at $13.48 | Balance: $79275.45
# 588: BUY  592.02 shares at $13.39 | Balance: $71347.91
# 589: SELL 2740.81 shares at $13.18 | Balance: $107468.86
# 590: BUY  799.22 shares at $13.45 | Balance: $96721.98
# 591: BUY  737.95 shares at $13.11 | Balance: $87049.78
# 592: SELL 1537.17 shares at $12.98 | Balance: $107009.38
# 593: HOLD | Current price: $13.43 | Balance: $107009.38
# 594: BUY  802.86 shares at $13.33 | Balance: $96308.44
# 595: BUY  705.56 shares at $13.65 | Balance: $86677.60
# 596: SELL 1508.41 shares at $13.85 | Balance: $107576.12
# 597: HOLD | Current price: $13.92 | Balance: $107576.12
# 598: HOLD | Current price: $14.04 | Balance: $107576.12
# 599: BUY  770.46 shares at $13.96 | Balance: $96818.51
# 600: BUY  696.73 shares at $13.90 | Balance: $87136.66
# 601: SELL 1467.20 shares at $13.95 | Balance: $107607.21
# 602: HOLD | Current price: $14.06 | Balance: $107607.21
# 603: HOLD | Current price: $13.99 | Balance: $107607.21
# 604: BUY  774.93 shares at $13.89 | Balance: $96846.49
# 605: BUY  713.25 shares at $13.58 | Balance: $87161.84
# 606: SELL 1488.18 shares at $13.53 | Balance: $107302.21
# 607: BUY  788.53 shares at $13.61 | Balance: $96571.99
# 608: BUY  707.47 shares at $13.65 | Balance: $86914.79
# 609: SELL 1496.00 shares at $14.14 | Balance: $108069.83
# 610: HOLD | Current price: $14.16 | Balance: $108069.83
# 611: BUY  759.24 shares at $14.23 | Balance: $97262.85
# 612: SELL 759.24 shares at $14.40 | Balance: $108199.44
# 613: BUY  745.23 shares at $14.52 | Balance: $97379.50
# 614: SELL 745.23 shares at $14.38 | Balance: $108095.91
# 615: BUY  747.11 shares at $14.47 | Balance: $97286.32
# 616: BUY  672.60 shares at $14.46 | Balance: $87557.69
# 617: SELL 1419.71 shares at $14.69 | Balance: $108408.59
# 618: BUY  734.19 shares at $14.77 | Balance: $97567.73
# 619: SELL 734.19 shares at $14.93 | Balance: $108528.95
# 620: BUY  719.42 shares at $15.09 | Balance: $97676.05
# 621: BUY  648.50 shares at $15.06 | Balance: $87908.45
# 622: SELL 1367.92 shares at $15.12 | Balance: $108585.50
# 623: BUY  719.53 shares at $15.09 | Balance: $97726.95
# 624: SELL 719.53 shares at $15.05 | Balance: $108555.69
# 625: BUY  724.03 shares at $14.99 | Balance: $97700.12
# 626: SELL 724.03 shares at $15.17 | Balance: $108682.14
# 627: BUY  709.17 shares at $15.33 | Balance: $97813.93
# 628: BUY  640.28 shares at $15.28 | Balance: $88032.53
# 629: BUY  586.46 shares at $15.01 | Balance: $79229.28
# 630: BUY  519.04 shares at $15.26 | Balance: $71306.35
# 631: SELL 2454.95 shares at $15.01 | Balance: $108166.49
# 632: BUY  678.07 shares at $15.95 | Balance: $97349.84
# 633: BUY  613.05 shares at $15.88 | Balance: $87614.86
# 634: SELL 1291.12 shares at $15.97 | Balance: $108239.53
# 635: BUY  669.02 shares at $16.18 | Balance: $97415.57
# 636: BUY  597.54 shares at $16.30 | Balance: $87674.02
# 637: BUY  538.13 shares at $16.29 | Balance: $78906.62
# 638: SELL 1804.68 shares at $16.25 | Balance: $108240.36
# 639: HOLD | Current price: $16.42 | Balance: $108240.36
# 640: BUY  653.22 shares at $16.57 | Balance: $97416.32
# 641: BUY  581.80 shares at $16.74 | Balance: $87674.69
# 642: BUY  515.00 shares at $17.02 | Balance: $78907.22
# 643: BUY  448.00 shares at $17.61 | Balance: $71016.50
# 644: BUY  403.00 shares at $17.62 | Balance: $63914.85
# 645: BUY  356.07 shares at $17.95 | Balance: $57523.36
# 646: BUY  316.15 shares at $18.19 | Balance: $51771.03
# 647: BUY  291.28 shares at $17.77 | Balance: $46593.92
# 648: SELL 3564.51 shares at $17.94 | Balance: $110527.18
# 649: HOLD | Current price: $17.93 | Balance: $110527.18
# 650: HOLD | Current price: $18.39 | Balance: $110527.18
# 651: BUY  603.22 shares at $18.32 | Balance: $99474.46
# 652: SELL 603.22 shares at $18.44 | Balance: $110599.35
# 653: HOLD | Current price: $18.66 | Balance: $110599.35
# 654: HOLD | Current price: $18.78 | Balance: $110599.35
# 655: BUY  578.39 shares at $19.12 | Balance: $99539.42
# 656: SELL 578.39 shares at $19.37 | Balance: $110744.57
# 657: HOLD | Current price: $19.45 | Balance: $110744.57
# 658: BUY  568.78 shares at $19.47 | Balance: $99670.11
# 659: SELL 568.78 shares at $19.04 | Balance: $110500.40
# 660: BUY  583.49 shares at $18.94 | Balance: $99450.36
# 661: BUY  524.72 shares at $18.95 | Balance: $89505.33
# 662: BUY  462.40 shares at $19.36 | Balance: $80554.79
# 663: BUY  413.73 shares at $19.47 | Balance: $72499.31
# 664: SELL 1984.33 shares at $19.71 | Balance: $111619.02
# 665: HOLD | Current price: $20.29 | Balance: $111619.02
# 666: HOLD | Current price: $21.06 | Balance: $111619.02
# 667: HOLD | Current price: $20.91 | Balance: $111619.02
# 668: BUY  533.72 shares at $20.91 | Balance: $100457.11
# 669: SELL 533.72 shares at $21.47 | Balance: $111915.04
# 670: BUY  517.13 shares at $21.64 | Balance: $100723.54
# 671: BUY  468.09 shares at $21.52 | Balance: $90651.18
# 672: SELL 985.23 shares at $21.41 | Balance: $111739.95
# 673: BUY  524.91 shares at $21.29 | Balance: $100565.96
# 674: BUY  463.91 shares at $21.68 | Balance: $90509.36
# 675: SELL 988.82 shares at $21.95 | Balance: $112209.72
# 676: BUY  508.71 shares at $22.06 | Balance: $100988.74
# 677: SELL 508.71 shares at $21.78 | Balance: $112068.73
# 678: HOLD | Current price: $21.41 | Balance: $112068.73
# 679: HOLD | Current price: $22.09 | Balance: $112068.73
# 680: HOLD | Current price: $22.48 | Balance: $112068.73
# 681: HOLD | Current price: $22.30 | Balance: $112068.73
# 682: BUY  495.19 shares at $22.63 | Balance: $100861.86
# 683: SELL 495.19 shares at $22.72 | Balance: $112113.83
# 684: BUY  499.52 shares at $22.44 | Balance: $100902.44
# 685: BUY  451.18 shares at $22.36 | Balance: $90812.20
# 686: BUY  408.30 shares at $22.24 | Balance: $81730.98
# 687: BUY  378.12 shares at $21.62 | Balance: $73557.88
# 688: BUY  355.03 shares at $20.72 | Balance: $66202.09
# 689: SELL 2092.14 shares at $21.77 | Balance: $111758.34
# 690: BUY  514.39 shares at $21.73 | Balance: $100582.51
# 691: BUY  479.42 shares at $20.98 | Balance: $90524.26
# 692: SELL 993.81 shares at $20.46 | Balance: $110861.16
# 693: BUY  542.96 shares at $20.42 | Balance: $99775.04
# 694: SELL 542.96 shares at $20.01 | Balance: $110639.71
# 695: HOLD | Current price: $21.79 | Balance: $110639.71
# 696: HOLD | Current price: $21.70 | Balance: $110639.71
# 697: HOLD | Current price: $21.54 | Balance: $110639.71
# 698: BUY  530.48 shares at $20.86 | Balance: $99575.74
# 699: SELL 530.48 shares at $20.79 | Balance: $110604.66
# 700: HOLD | Current price: $20.93 | Balance: $110604.66
# 701: BUY  532.28 shares at $20.78 | Balance: $99544.19
# 702: BUY  493.10 shares at $20.19 | Balance: $89589.77
# 703: BUY  440.49 shares at $20.34 | Balance: $80630.80
# 704: BUY  397.35 shares at $20.29 | Balance: $72567.72
# 705: BUY  356.99 shares at $20.33 | Balance: $65310.94
# 706: BUY  320.53 shares at $20.38 | Balance: $58779.85
# 707: BUY  290.42 shares at $20.24 | Balance: $52901.87
# 708: SELL 2831.16 shares at $19.94 | Balance: $109345.13
# 709: BUY  553.48 shares at $19.76 | Balance: $98410.62
# 710: BUY  504.60 shares at $19.50 | Balance: $88569.56
# 711: BUY  467.81 shares at $18.93 | Balance: $79712.60
# 712: BUY  420.82 shares at $18.94 | Balance: $71741.34
# 713: SELL 1946.70 shares at $20.05 | Balance: $110764.38
# 714: BUY  556.83 shares at $19.89 | Balance: $99687.94
# 715: BUY  489.21 shares at $20.38 | Balance: $89719.14
# 716: SELL 1046.05 shares at $20.19 | Balance: $110838.88
# 717: HOLD | Current price: $20.08 | Balance: $110838.88
# 718: HOLD | Current price: $20.44 | Balance: $110838.88
# 719: HOLD | Current price: $20.68 | Balance: $110838.88
# 720: HOLD | Current price: $20.63 | Balance: $110838.88
# 721: HOLD | Current price: $20.04 | Balance: $110838.88
# 722: BUY  549.98 shares at $20.15 | Balance: $99754.99
# 723: SELL 549.98 shares at $20.10 | Balance: $110810.20
# 724: BUY  542.94 shares at $20.41 | Balance: $99729.18
# 725: SELL 542.94 shares at $20.42 | Balance: $110815.24
# 726: BUY  534.68 shares at $20.73 | Balance: $99733.72
# 727: SELL 534.68 shares at $20.40 | Balance: $110640.52
# 728: HOLD | Current price: $20.58 | Balance: $110640.52
# 729: HOLD | Current price: $20.43 | Balance: $110640.52
# 730: BUY  542.04 shares at $20.41 | Balance: $99576.47
# 731: SELL 542.04 shares at $20.50 | Balance: $110690.85
# 732: HOLD | Current price: $20.92 | Balance: $110690.85
# 733: HOLD | Current price: $20.98 | Balance: $110690.85
# 734: BUY  529.13 shares at $20.92 | Balance: $99621.77
# 735: BUY  482.87 shares at $20.63 | Balance: $89659.59
# 736: SELL 1012.01 shares at $20.79 | Balance: $110698.46
# 737: HOLD | Current price: $20.38 | Balance: $110698.46
# 738: BUY  541.85 shares at $20.43 | Balance: $99628.61
# 739: BUY  485.57 shares at $20.52 | Balance: $89665.75
# 740: SELL 1027.42 shares at $20.32 | Balance: $110546.28
# 741: BUY  530.02 shares at $20.86 | Balance: $99491.65
# 742: BUY  470.16 shares at $21.16 | Balance: $89542.49
# 743: SELL 1000.17 shares at $21.41 | Balance: $110953.67
# 744: BUY  509.35 shares at $21.78 | Balance: $99858.30
# 745: SELL 509.35 shares at $21.64 | Balance: $110879.81
# 746: HOLD | Current price: $21.92 | Balance: $110879.81
# 747: BUY  510.45 shares at $21.72 | Balance: $99791.83
# 748: BUY  462.28 shares at $21.59 | Balance: $89812.65
# 749: SELL 972.74 shares at $21.39 | Balance: $110618.78
# 750: BUY  511.98 shares at $21.61 | Balance: $99556.91
# 751: SELL 511.98 shares at $21.68 | Balance: $110654.26
# 752: HOLD | Current price: $21.68 | Balance: $110654.26
# 753: HOLD | Current price: $21.65 | Balance: $110654.26
# 754: BUY  504.35 shares at $21.94 | Balance: $99588.83
# 755: SELL 504.35 shares at $21.58 | Balance: $110473.77
# 756: BUY  512.27 shares at $21.57 | Balance: $99426.40
# 757: SELL 512.27 shares at $21.46 | Balance: $110420.53
# 758: BUY  537.73 shares at $20.53 | Balance: $99378.48
# 759: BUY  484.03 shares at $20.53 | Balance: $89440.63
# 760: SELL 1021.76 shares at $20.90 | Balance: $110793.94
# 761: BUY  521.36 shares at $21.25 | Balance: $99714.54
# 762: BUY  457.14 shares at $21.81 | Balance: $89743.09
# 763: BUY  414.10 shares at $21.67 | Balance: $80768.78
# 764: BUY  372.09 shares at $21.71 | Balance: $72691.90
# 765: BUY  330.58 shares at $21.99 | Balance: $65422.71
# 766: BUY  294.25 shares at $22.23 | Balance: $58880.44
# 767: SELL 2389.51 shares at $22.18 | Balance: $111868.69
# 768: HOLD | Current price: $22.14 | Balance: $111868.69
# 769: BUY  504.62 shares at $22.17 | Balance: $100681.82
# 770: BUY  453.45 shares at $22.20 | Balance: $90613.64
# 771: BUY  402.73 shares at $22.50 | Balance: $81552.27
# 772: BUY  361.48 shares at $22.56 | Balance: $73397.05
# 773: SELL 1722.28 shares at $22.53 | Balance: $112199.40
# 774: HOLD | Current price: $22.73 | Balance: $112199.40
# 775: BUY  484.73 shares at $23.15 | Balance: $100979.46
# 776: SELL 484.73 shares at $23.76 | Balance: $112494.40
# 777: HOLD | Current price: $23.43 | Balance: $112494.40
# 778: HOLD | Current price: $23.89 | Balance: $112494.40
# 779: BUY  475.35 shares at $23.67 | Balance: $101244.96
# 780: SELL 475.35 shares at $23.69 | Balance: $112504.41
# 781: HOLD | Current price: $24.13 | Balance: $112504.41
# 782: HOLD | Current price: $24.10 | Balance: $112504.41
# 783: HOLD | Current price: $24.05 | Balance: $112504.41
# 784: HOLD | Current price: $23.71 | Balance: $112504.41
# 785: HOLD | Current price: $23.76 | Balance: $112504.41
# 786: BUY  466.71 shares at $24.11 | Balance: $101253.97
# 787: SELL 466.71 shares at $23.94 | Balance: $112425.41
# 788: HOLD | Current price: $24.15 | Balance: $112425.41
# 789: HOLD | Current price: $24.30 | Balance: $112425.41
# 790: HOLD | Current price: $23.67 | Balance: $112425.41
# 791: BUY  476.53 shares at $23.59 | Balance: $101182.87
# 792: BUY  422.99 shares at $23.92 | Balance: $91064.58
# 793: BUY  373.34 shares at $24.39 | Balance: $81958.12
# 794: BUY  331.97 shares at $24.69 | Balance: $73762.31
# 795: SELL 1604.82 shares at $24.99 | Balance: $113870.21
# 796: BUY  454.24 shares at $25.07 | Balance: $102483.19
# 797: BUY  408.71 shares at $25.08 | Balance: $92234.87
# 798: BUY  369.63 shares at $24.95 | Balance: $83011.38
# 799: BUY  332.00 shares at $25.00 | Balance: $74710.24
# 800: SELL 1564.58 shares at $24.67 | Balance: $113310.03
# 801: HOLD | Current price: $24.06 | Balance: $113310.03
# 802: HOLD | Current price: $23.76 | Balance: $113310.03
# 803: BUY  465.67 shares at $24.33 | Balance: $101979.02
# 804: SELL 465.67 shares at $23.83 | Balance: $113073.53
# 805: BUY  480.15 shares at $23.55 | Balance: $101766.18
# 806: BUY  430.88 shares at $23.62 | Balance: $91589.56
# 807: BUY  381.94 shares at $23.98 | Balance: $82430.61
# 808: SELL 1292.97 shares at $23.81 | Balance: $113221.66
# 809: BUY  485.79 shares at $23.31 | Balance: $101899.49
# 810: BUY  447.09 shares at $22.79 | Balance: $91709.54
# 811: BUY  403.85 shares at $22.71 | Balance: $82538.59
# 812: BUY  360.59 shares at $22.89 | Balance: $74284.73
# 813: BUY  331.15 shares at $22.43 | Balance: $66856.26
# 814: SELL 2028.47 shares at $22.49 | Balance: $112475.86
# 815: BUY  496.14 shares at $22.67 | Balance: $101228.27
# 816: BUY  436.20 shares at $23.21 | Balance: $91105.45
# 817: BUY  395.74 shares at $23.02 | Balance: $81994.90
# 818: SELL 1328.08 shares at $22.59 | Balance: $112001.94
# 819: HOLD | Current price: $21.78 | Balance: $112001.94
# 820: HOLD | Current price: $22.64 | Balance: $112001.94
# 821: HOLD | Current price: $21.91 | Balance: $112001.94
# 822: HOLD | Current price: $22.03 | Balance: $112001.94
# 823: BUY  514.50 shares at $21.77 | Balance: $100801.75
# 824: SELL 514.50 shares at $21.57 | Balance: $111900.15
# 825: HOLD | Current price: $21.26 | Balance: $111900.15
# 826: BUY  525.23 shares at $21.31 | Balance: $100710.13
# 827: BUY  488.88 shares at $20.60 | Balance: $90639.12
# 828: SELL 1014.11 shares at $20.88 | Balance: $111813.09
# 829: BUY  537.15 shares at $20.82 | Balance: $100631.78
# 830: BUY  504.96 shares at $19.93 | Balance: $90568.60
# 831: SELL 1042.11 shares at $19.21 | Balance: $110582.70
# 832: HOLD | Current price: $19.54 | Balance: $110582.70
# 833: BUY  570.40 shares at $19.39 | Balance: $99524.43
# 834: SELL 570.40 shares at $19.39 | Balance: $110584.13
# 835: HOLD | Current price: $19.17 | Balance: $110584.13
# 836: HOLD | Current price: $18.77 | Balance: $110584.13
# 837: HOLD | Current price: $18.85 | Balance: $110584.13
# 838: HOLD | Current price: $20.20 | Balance: $110584.13
# 839: BUY  552.02 shares at $20.03 | Balance: $99525.71
# 840: BUY  496.12 shares at $20.06 | Balance: $89573.14
# 841: BUY  438.85 shares at $20.41 | Balance: $80615.83
# 842: SELL 1487.00 shares at $21.05 | Balance: $111924.08
# 843: HOLD | Current price: $20.89 | Balance: $111924.08
# 844: BUY  537.60 shares at $20.82 | Balance: $100731.67
# 845: BUY  478.57 shares at $21.05 | Balance: $90658.50
# 846: BUY  433.71 shares at $20.90 | Balance: $81592.65
# 847: BUY  389.74 shares at $20.94 | Balance: $73433.39
# 848: SELL 1839.62 shares at $20.57 | Balance: $111267.05
# 849: HOLD | Current price: $19.24 | Balance: $111267.05
# 850: BUY  569.31 shares at $19.54 | Balance: $100140.34
# 851: BUY  525.82 shares at $19.04 | Balance: $90126.31
# 852: SELL 1095.13 shares at $18.92 | Balance: $110848.44
# 853: BUY  573.29 shares at $19.34 | Balance: $99763.60
# 854: SELL 573.29 shares at $19.25 | Balance: $110799.51
# 855: BUY  585.70 shares at $18.92 | Balance: $99719.56
# 856: BUY  547.71 shares at $18.21 | Balance: $89747.60
# 857: SELL 1133.40 shares at $18.53 | Balance: $110749.17
# 858: BUY  580.82 shares at $19.07 | Balance: $99674.25
# 859: BUY  530.27 shares at $18.80 | Balance: $89706.83
# 860: SELL 1111.09 shares at $18.63 | Balance: $110409.99
# 861: HOLD | Current price: $18.55 | Balance: $110409.99
# 862: BUY  594.32 shares at $18.58 | Balance: $99368.99
# 863: SELL 594.32 shares at $18.32 | Balance: $110257.80
# 864: HOLD | Current price: $18.40 | Balance: $110257.80
# ...
# 3486: BUY  67.10 shares at $177.30 | Balance: $107065.65
# 3487: SELL 227.34 shares at $177.25 | Balance: $147361.90
# 3488: BUY  81.83 shares at $180.09 | Balance: $132625.71
# 3489: SELL 81.83 shares at $180.95 | Balance: $147432.27
# 3490: HOLD | Current price: $179.58 | Balance: $147432.27
# 3491: BUY  82.27 shares at $179.21 | Balance: $132689.04
# 3492: BUY  74.62 shares at $177.82 | Balance: $119420.14
# 3493: SELL 156.89 shares at $180.57 | Balance: $147749.36
# 3494: HOLD | Current price: $180.96 | Balance: $147749.36
# 3495: BUY  80.39 shares at $183.79 | Balance: $132974.42
# 3496: SELL 80.39 shares at $183.31 | Balance: $147710.77
# 3497: BUY  80.30 shares at $183.95 | Balance: $132939.70
# 3498: SELL 80.30 shares at $186.01 | Balance: $147876.19
# 3499: HOLD | Current price: $184.92 | Balance: $147876.19
# 3500: HOLD | Current price: $185.01 | Balance: $147876.19
# 3501: HOLD | Current price: $183.96 | Balance: $147876.19
# 3502: BUY  79.08 shares at $187.00 | Balance: $133088.57
# 3503: BUY  71.29 shares at $186.68 | Balance: $119779.71
# 3504: BUY  64.65 shares at $185.27 | Balance: $107801.74
# 3505: SELL 215.02 shares at $188.06 | Balance: $148238.77
# 3506: BUY  78.33 shares at $189.25 | Balance: $133414.90
# 3507: BUY  70.37 shares at $189.59 | Balance: $120073.41
# 3508: SELL 148.70 shares at $193.97 | Balance: $148916.71
# 3509: HOLD | Current price: $192.46 | Balance: $148916.71
# 3510: HOLD | Current price: $191.33 | Balance: $148916.71
# 3511: BUY  77.64 shares at $191.81 | Balance: $134025.04
# 3512: BUY  70.29 shares at $190.68 | Balance: $120622.54
# 3513: SELL 147.93 shares at $188.61 | Balance: $148522.77
# 3514: HOLD | Current price: $188.08 | Balance: $148522.77
# 3515: BUY  78.26 shares at $189.77 | Balance: $133670.50
# 3516: BUY  70.15 shares at $190.54 | Balance: $120303.45
# 3517: SELL 148.42 shares at $190.69 | Balance: $148605.30
# 3518: BUY  76.60 shares at $193.99 | Balance: $133744.77
# 3519: BUY  69.04 shares at $193.73 | Balance: $120370.29
# 3520: SELL 145.64 shares at $195.10 | Balance: $148784.91
# 3521: HOLD | Current price: $193.13 | Balance: $148784.91
# 3522: BUY  77.52 shares at $191.94 | Balance: $133906.42
# 3523: SELL 77.52 shares at $192.75 | Balance: $148847.70
# 3524: HOLD | Current price: $193.62 | Balance: $148847.70
# 3525: BUY  76.53 shares at $194.50 | Balance: $133962.93
# 3526: SELL 76.53 shares at $193.22 | Balance: $148749.75
# 3527: HOLD | Current price: $195.83 | Balance: $148749.75
# 3528: HOLD | Current price: $196.45 | Balance: $148749.75
# 3529: BUY  76.04 shares at $195.61 | Balance: $133874.77
# 3530: SELL 76.04 shares at $192.58 | Balance: $148519.33
# 3531: HOLD | Current price: $191.17 | Balance: $148519.33
# 3532: BUY  81.61 shares at $181.99 | Balance: $133667.40
# 3533: BUY  74.74 shares at $178.85 | Balance: $120300.66
# 3534: BUY  66.91 shares at $179.80 | Balance: $108270.59
# 3535: SELL 223.25 shares at $178.19 | Balance: $148052.17
# 3536: HOLD | Current price: $177.97 | Balance: $148052.17
# 3537: BUY  83.27 shares at $177.79 | Balance: $133246.95
# 3538: BUY  74.25 shares at $179.46 | Balance: $119922.26
# 3539: SELL 157.52 shares at $177.45 | Balance: $147874.62
# 3540: HOLD | Current price: $176.57 | Balance: $147874.62
# 3541: BUY  84.99 shares at $174.00 | Balance: $133087.16
# 3542: BUY  76.27 shares at $174.49 | Balance: $119778.44
# 3543: SELL 161.26 shares at $175.84 | Balance: $148133.96
# 3544: HOLD | Current price: $177.23 | Balance: $148133.96
# 3545: BUY  81.79 shares at $181.12 | Balance: $133320.56
# 3546: BUY  75.59 shares at $176.38 | Balance: $119988.50
# 3547: SELL 157.37 shares at $178.61 | Balance: $148097.23
# 3548: HOLD | Current price: $180.19 | Balance: $148097.23
# 3549: BUY  80.44 shares at $184.12 | Balance: $133287.51
# 3550: SELL 80.44 shares at $187.65 | Balance: $148381.16
# 3551: BUY  78.98 shares at $187.87 | Balance: $133543.05
# 3552: SELL 78.98 shares at $189.46 | Balance: $148506.75
# 3553: BUY  78.29 shares at $189.70 | Balance: $133656.07
# 3554: SELL 78.29 shares at $182.91 | Balance: $147975.19
# 3555: HOLD | Current price: $177.56 | Balance: $147975.19
# 3556: BUY  83.05 shares at $178.18 | Balance: $133177.67
# 3557: SELL 83.05 shares at $179.36 | Balance: $148073.19
# 3558: BUY  83.99 shares at $176.30 | Balance: $133265.87
# 3559: BUY  76.50 shares at $174.21 | Balance: $119939.28
# 3560: BUY  68.25 shares at $175.74 | Balance: $107945.35
# 3561: BUY  61.68 shares at $175.01 | Balance: $97150.82
# 3562: SELL 290.41 shares at $177.97 | Balance: $148835.84
# 3563: BUY  83.12 shares at $179.07 | Balance: $133952.26
# 3564: SELL 83.12 shares at $175.49 | Balance: $148538.29
# 3565: BUY  85.40 shares at $173.93 | Balance: $133684.46
# 3566: SELL 85.40 shares at $174.79 | Balance: $148611.73
# 3567: HOLD | Current price: $176.08 | Balance: $148611.73
# 3568: BUY  86.42 shares at $171.96 | Balance: $133750.56
# 3569: SELL 86.42 shares at $170.43 | Balance: $148479.51
# 3570: HOLD | Current price: $170.69 | Balance: $148479.51
# 3571: BUY  86.72 shares at $171.21 | Balance: $133631.56
# 3572: BUY  76.91 shares at $173.75 | Balance: $120268.40
# 3573: SELL 163.63 shares at $172.40 | Balance: $148478.88
# 3574: BUY  85.50 shares at $173.66 | Balance: $133630.99
# 3575: BUY  76.40 shares at $174.91 | Balance: $120267.89
# 3576: BUY  67.76 shares at $177.49 | Balance: $108241.10
# 3577: SELL 229.66 shares at $178.99 | Balance: $149347.94
# 3578: HOLD | Current price: $178.39 | Balance: $149347.94
# 3579: HOLD | Current price: $179.80 | Balance: $149347.94
# 3580: BUY  82.65 shares at $180.71 | Balance: $134413.15
# 3581: BUY  75.15 shares at $178.85 | Balance: $120971.83
# 3582: BUY  67.69 shares at $178.72 | Balance: $108874.65
# 3583: SELL 225.49 shares at $177.15 | Balance: $148819.69
# 3584: HOLD | Current price: $175.84 | Balance: $148819.69
# 3585: HOLD | Current price: $175.46 | Balance: $148819.69
# 3586: BUY  86.08 shares at $172.88 | Balance: $133937.72
# 3587: SELL 86.08 shares at $173.00 | Balance: $148830.02
# 3588: BUY  85.81 shares at $173.44 | Balance: $133947.02
# 3589: SELL 85.81 shares at $171.10 | Balance: $148629.22
# 3590: BUY  89.06 shares at $166.89 | Balance: $133766.30
# 3591: BUY  79.52 shares at $168.22 | Balance: $120389.67
# 3592: SELL 168.58 shares at $170.29 | Balance: $149096.63
# 3593: HOLD | Current price: $170.77 | Balance: $149096.63
# 3594: HOLD | Current price: $173.97 | Balance: $149096.63
# 3595: BUY  83.96 shares at $177.57 | Balance: $134186.96
# 3596: BUY  75.96 shares at $176.65 | Balance: $120768.27
# 3597: BUY  67.38 shares at $179.23 | Balance: $108691.44
# 3598: SELL 227.31 shares at $181.82 | Balance: $150020.72
# 3599: BUY  82.03 shares at $182.89 | Balance: $135018.65
# 3600: BUY  74.02 shares at $182.41 | Balance: $121516.78
# 3601: BUY  65.19 shares at $186.40 | Balance: $109365.11
# 3602: SELL 221.24 shares at $184.80 | Balance: $150249.99
# 3603: HOLD | Current price: $187.44 | Balance: $150249.99
# 3604: HOLD | Current price: $188.01 | Balance: $150249.99
# 3605: BUY  79.20 shares at $189.71 | Balance: $135225.00
# 3606: BUY  71.29 shares at $189.69 | Balance: $121702.50
# 3607: SELL 150.49 shares at $191.45 | Balance: $150513.27
# 3608: BUY  78.95 shares at $190.64 | Balance: $135461.94
# 3609: BUY  70.81 shares at $191.31 | Balance: $121915.75
# 3610: SELL 149.76 shares at $189.97 | Balance: $150365.49
# 3611: HOLD | Current price: $189.79 | Balance: $150365.49
# 3612: HOLD | Current price: $190.40 | Balance: $150365.49
# 3613: HOLD | Current price: $189.37 | Balance: $150365.49
# 3614: BUY  79.16 shares at $189.95 | Balance: $135328.94
# 3615: BUY  70.76 shares at $191.24 | Balance: $121796.04
# 3616: SELL 149.92 shares at $189.43 | Balance: $150196.24
# 3617: HOLD | Current price: $193.42 | Balance: $150196.24
# 3618: HOLD | Current price: $192.32 | Balance: $150196.24
# 3619: BUY  77.31 shares at $194.27 | Balance: $135176.62
# 3620: SELL 77.31 shares at $195.71 | Balance: $150307.57
# 3621: HOLD | Current price: $193.18 | Balance: $150307.57
# 3622: BUY  77.20 shares at $194.71 | Balance: $135276.81
# 3623: BUY  68.34 shares at $197.96 | Balance: $121749.13
# 3624: BUY  61.46 shares at $198.11 | Balance: $109574.22
# 3625: BUY  55.46 shares at $197.57 | Balance: $98616.80
# 3626: BUY  50.34 shares at $195.89 | Balance: $88755.12
# 3627: BUY  45.07 shares at $196.94 | Balance: $79879.61
# 3628: BUY  41.00 shares at $194.83 | Balance: $71891.65
# 3629: SELL 398.86 shares at $194.68 | Balance: $149541.12
# 3630: HOLD | Current price: $193.60 | Balance: $149541.12
# 3631: BUY  77.46 shares at $193.05 | Balance: $134587.01
# 3632: BUY  69.68 shares at $193.15 | Balance: $121128.31
# 3633: BUY  62.57 shares at $193.58 | Balance: $109015.48
# 3634: SELL 209.72 shares at $192.53 | Balance: $149391.94
# 3635: BUY  80.47 shares at $185.64 | Balance: $134452.74
# 3636: SELL 80.47 shares at $184.25 | Balance: $149280.08
# 3637: BUY  82.06 shares at $181.91 | Balance: $134352.07
# 3638: BUY  74.15 shares at $181.18 | Balance: $120916.86
# 3639: BUY  65.16 shares at $185.56 | Balance: $108825.18
# 3640: BUY  58.78 shares at $185.14 | Balance: $97942.66
# 3641: BUY  52.60 shares at $186.19 | Balance: $88148.39
# 3642: BUY  47.50 shares at $185.59 | Balance: $79333.55
# 3643: BUY  42.67 shares at $185.92 | Balance: $71400.20
# 3644: SELL 422.93 shares at $183.63 | Balance: $149062.91
# 3645: BUY  81.60 shares at $182.68 | Balance: $134156.62
# 3646: BUY  71.12 shares at $188.63 | Balance: $120740.96
# 3647: BUY  63.03 shares at $191.56 | Balance: $108666.86
# 3648: BUY  56.05 shares at $193.89 | Balance: $97800.17
# 3649: SELL 271.80 shares at $195.18 | Balance: $150849.19
# 3650: BUY  77.56 shares at $194.50 | Balance: $135764.28
# 3651: SELL 77.56 shares at $194.17 | Balance: $150823.60
# 3652: BUY  78.38 shares at $192.42 | Balance: $135741.24
# 3653: BUY  70.80 shares at $191.73 | Balance: $122167.12
# 3654: BUY  64.97 shares at $188.04 | Balance: $109950.40
# 3655: SELL 214.15 shares at $184.40 | Balance: $149439.54
# 3656: HOLD | Current price: $186.86 | Balance: $149439.54
# 3657: HOLD | Current price: $185.85 | Balance: $149439.54
# 3658: HOLD | Current price: $187.68 | Balance: $149439.54
# 3659: HOLD | Current price: $189.30 | Balance: $149439.54
# 3660: BUY  78.90 shares at $189.41 | Balance: $134495.58
# 3661: SELL 78.90 shares at $188.32 | Balance: $149353.54
# 3662: HOLD | Current price: $188.85 | Balance: $149353.54
# 3663: HOLD | Current price: $187.15 | Balance: $149353.54
# 3664: HOLD | Current price: $185.04 | Balance: $149353.54
# 3665: BUY  81.10 shares at $184.15 | Balance: $134418.18
# 3666: SELL 81.10 shares at $183.86 | Balance: $149330.02
# 3667: BUY  81.91 shares at $182.31 | Balance: $134397.02
# 3668: SELL 81.91 shares at $181.56 | Balance: $149268.59
# 3669: BUY  81.87 shares at $182.32 | Balance: $134341.73
# 3670: BUY  72.87 shares at $184.37 | Balance: $120907.55
# 3671: BUY  66.24 shares at $182.52 | Balance: $108816.80
# 3672: SELL 220.98 shares at $181.16 | Balance: $148849.63
# 3673: BUY  81.50 shares at $182.63 | Balance: $133964.66
# 3674: SELL 81.50 shares at $181.42 | Balance: $148751.01
# 3675: BUY  82.30 shares at $180.75 | Balance: $133875.91
# 3676: SELL 82.30 shares at $179.66 | Balance: $148661.30
# 3677: HOLD | Current price: $175.10 | Balance: $148661.30
# 3678: BUY  87.39 shares at $170.12 | Balance: $133795.17
# 3679: SELL 87.39 shares at $169.12 | Balance: $148573.92
# 3680: BUY  87.91 shares at $169.00 | Balance: $133716.53
# 3681: BUY  78.32 shares at $170.73 | Balance: $120344.87
# 3682: BUY  69.66 shares at $172.75 | Balance: $108310.39
# 3683: BUY  62.52 shares at $173.23 | Balance: $97479.35
# 3684: BUY  56.96 shares at $171.13 | Balance: $87731.41
# 3685: BUY  50.71 shares at $173.00 | Balance: $78958.27
# 3686: BUY  45.74 shares at $172.62 | Balance: $71062.44
# 3687: SELL 451.84 shares at $173.72 | Balance: $149555.62
# 3688: HOLD | Current price: $176.08 | Balance: $149555.62
# 3689: HOLD | Current price: $178.67 | Balance: $149555.62
# 3690: HOLD | Current price: $171.37 | Balance: $149555.62
# 3691: BUY  86.81 shares at $172.28 | Balance: $134600.06
# 3692: SELL 86.81 shares at $170.85 | Balance: $149431.48
# 3693: BUY  88.05 shares at $169.71 | Balance: $134488.33
# 3694: BUY  77.60 shares at $173.31 | Balance: $121039.50
# 3695: BUY  70.59 shares at $171.48 | Balance: $108935.55
# 3696: SELL 236.24 shares at $170.03 | Balance: $149102.78
# 3697: HOLD | Current price: $168.84 | Balance: $149102.78
# 3698: BUY  87.89 shares at $169.65 | Balance: $134192.50
# 3699: SELL 87.89 shares at $168.82 | Balance: $149029.84
# 3700: BUY  87.88 shares at $169.58 | Balance: $134126.85
# 3701: BUY  79.62 shares at $168.45 | Balance: $120714.17
# 3702: SELL 167.51 shares at $169.67 | Balance: $149134.89
# 3703: BUY  88.89 shares at $167.78 | Balance: $134221.40
# 3704: BUY  76.68 shares at $175.04 | Balance: $120799.26
# 3705: SELL 165.57 shares at $176.55 | Balance: $150030.22
# 3706: HOLD | Current price: $172.69 | Balance: $150030.22
# 3707: BUY  88.58 shares at $169.38 | Balance: $135027.19
# 3708: BUY  80.37 shares at $168.00 | Balance: $121524.47
# 3709: BUY  72.75 shares at $167.04 | Balance: $109372.03
# 3710: SELL 241.70 shares at $165.00 | Balance: $149252.72
# 3711: HOLD | Current price: $165.84 | Balance: $149252.72
# 3712: BUY  89.43 shares at $166.90 | Balance: $134327.45
# 3713: SELL 89.43 shares at $169.02 | Balance: $149442.30
# 3714: BUY  87.96 shares at $169.89 | Balance: $134498.07
# 3715: BUY  79.44 shares at $169.30 | Balance: $121048.27
# 3716: SELL 167.41 shares at $173.50 | Balance: $150093.52
# 3717: BUY  88.12 shares at $170.33 | Balance: $135084.17
# 3718: BUY  79.79 shares at $169.30 | Balance: $121575.75
# 3719: BUY  70.26 shares at $173.03 | Balance: $109418.17
# 3720: SELL 238.17 shares at $183.38 | Balance: $153094.14
# 3721: BUY  84.25 shares at $181.71 | Balance: $137784.72
# 3722: BUY  75.54 shares at $182.40 | Balance: $124006.25
# 3723: SELL 159.79 shares at $182.74 | Balance: $153206.60
# 3724: BUY  83.01 shares at $184.57 | Balance: $137885.94
# 3725: SELL 83.01 shares at $183.05 | Balance: $153080.43
# 3726: BUY  82.18 shares at $186.28 | Balance: $137772.39
# 3727: BUY  73.51 shares at $187.43 | Balance: $123995.15
# 3728: BUY  65.36 shares at $189.72 | Balance: $111595.63
# 3729: BUY  58.78 shares at $189.84 | Balance: $100436.07
# 3730: BUY  52.90 shares at $189.87 | Balance: $90392.46
# 3731: BUY  47.32 shares at $191.04 | Balance: $81353.22
# 3732: SELL 380.04 shares at $192.35 | Balance: $154453.51
# 3733: BUY  80.91 shares at $190.90 | Balance: $139008.15
# 3734: SELL 80.91 shares at $186.88 | Balance: $154128.26
# 3735: BUY  81.13 shares at $189.98 | Balance: $138715.43
# 3736: SELL 81.13 shares at $189.99 | Balance: $154129.07
# 3737: HOLD | Current price: $190.29 | Balance: $154129.07
# 3738: BUY  80.57 shares at $191.29 | Balance: $138716.16
# 3739: BUY  72.15 shares at $192.25 | Balance: $124844.54
# 3740: SELL 152.73 shares at $194.03 | Balance: $154478.27
# 3741: HOLD | Current price: $194.35 | Balance: $154478.27
# 3742: BUY  78.87 shares at $195.87 | Balance: $139030.45
# 3743: SELL 78.87 shares at $194.48 | Balance: $154368.65
# 3744: BUY  78.40 shares at $196.89 | Balance: $138931.78
# 3745: BUY  71.94 shares at $193.12 | Balance: $125038.60
# 3746: BUY  60.36 shares at $207.15 | Balance: $112534.74
# 3747: BUY  52.82 shares at $213.07 | Balance: $101281.27
# 3748: BUY  47.27 shares at $214.24 | Balance: $91153.14
# 3749: BUY  42.90 shares at $212.49 | Balance: $82037.83
# 3750: BUY  37.86 shares at $216.67 | Balance: $73834.05
# 3751: BUY  34.46 shares at $214.29 | Balance: $66450.64
# 3752: BUY  31.69 shares at $209.68 | Balance: $59805.58
# 3753: BUY  28.82 shares at $207.49 | Balance: $53825.02
# 3754: SELL 486.53 shares at $208.14 | Balance: $155090.69
# 3755: BUY  74.18 shares at $209.07 | Balance: $139581.62
# 3756: BUY  65.45 shares at $213.25 | Balance: $125623.46
# 3757: BUY  58.68 shares at $214.10 | Balance: $113061.11
# 3758: BUY  53.68 shares at $210.62 | Balance: $101755.00
# 3759: BUY  46.95 shares at $216.75 | Balance: $91579.50
# 3760: SELL 298.94 shares at $220.27 | Balance: $157426.30
# 3761: BUY  71.06 shares at $221.55 | Balance: $141683.67
#
# Final SELL 71.06 shares at $226.34 | Balance: $157766.66
# Action stats: {<Actions.Sell: 0>: 1705, <Actions.Buy: 1>: 2057}
# Final Balance: $157766.66

# %%
# Create your two charts below. Note, do not change the fig and ax variable names.

# Chart 1, a plot showing trading actions
fig, ax = plt.subplots()
env.unwrapped.render_all()
ax.set_title("PPO Agent - Trading Actions")
plt.show()

# Chart 2, a plot of the balance_history over time
fig2, ax2 = plt.subplots()
ax2.plot(balance_history)
ax2.set_title("PPO Agent - Balance over time")
ax2.set_xlabel("Steps")
ax2.set_ylabel("Balance ($)")

fig2.tight_layout()
plt.show()

# %%
#earnings, interest rates, news, macroeconomics, options flow, sentiment
